# %% [markdown]
# # Setup

# %%
import pandas as pd
import numpy as np

# To plot pretty figures
# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt
# plt.rcParams['axes.labelsize'] = 14
# plt.rcParams['xtick.labelsize'] = 12
# plt.rcParams['ytick.labelsize'] = 12

# %% [markdown]
# # Loading Data....

# %%
data=pd.read_csv('HireArt - Data Analyst Exercise 10.12.17 - Sheet1.csv')
data.head()
# Out:
#   Account manager                 Client Name Date of Contact
# 0     Milan Crona     Wyman, Farrell and Haag      2015-10-31
# 1    Aidan Pouros  Veum, McClure and Schuster      2013-12-07
# 2     Milan Crona             Armstrong Group      2013-11-02
# 3    Aidan Pouros   Lueilwitz, Moore and Hahn      2013-12-25
# 4   Chauncey Dach                Abbott Group      2016-03-21

# %%
#Count the numbers of Account manager
data2=data.groupby(['Account manager'])
data2.size()
# Out:
# Account manager
# Aidan Pouros       239
# Chauncey Dach      253
# Milan Crona        286
# Rigoberto White    222
# dtype: int64

# %%
#use pivot table to format data for each Account manager
data3=data.pivot_table(index='Account manager', columns='Date of Contact', values='Client Name', aggfunc='count')
data3
# Out:
# Date of Contact  2013-10-03  2013-10-04  2013-10-05  2013-10-06  2013-10-09  \
# Account manager
# Aidan Pouros            NaN         NaN         NaN         2.0         NaN
# Chauncey Dach           NaN         1.0         2.0         NaN         1.0
# Milan Crona             NaN         1.0         NaN         1.0         1.0
# Rigoberto White         1.0         1.0         1.0         NaN         NaN
#
# Date of Contact  2013-10-10  2013-10-11  2013-10-12  2013-10-13  2013-10-14  \
# Account manager
# Aidan Pouros            1.0         2.0         1.0         NaN         NaN
# Chauncey Dach           1.0         4.0         NaN         NaN         NaN
# Milan Crona             NaN         1.0         2.0         NaN         1.0
# Rigoberto White         NaN         NaN         NaN         1.0         NaN
#
# Date of Contact     ...      2017-09-15  2017-09-16  2017-09-17  2017-09-18  \
# Account manager     ...
# ...

# %% [markdown]
# # Data Analysis and Visualization

# %% [markdown]
# ## 1. Split out the contacts made by Account Manager: Milan Crona, name it as data_MilanCrona

# %%
data_MilanCrona=data.groupby(['Account manager']).get_group('Milan Crona')
data_MilanCrona.head()
# data_Crona=data4.pivot_table(index='Date of Contact', columns='Account manager', values='Client Name', aggfunc='count')
# data_Crona.sort_values('Milan Crona',ascending=False)
# Out:
#    Account manager              Client Name Date of Contact
# 0      Milan Crona  Wyman, Farrell and Haag      2015-10-31
# 2      Milan Crona          Armstrong Group      2013-11-02
# 10     Milan Crona        Mitchell and Sons      2016-11-14
# 11     Milan Crona  Brown, Wyman and Grimes      2015-10-17
# 13     Milan Crona             Stamm-Crooks      2014-09-23

# %%
# Convert that column into a datetime datatype
data_MilanCrona['Date of Contact'] = pd.to_datetime(data_MilanCrona['Date of Contact'])
# Set the datetime column as the index
data_MilanCrona.index = data_MilanCrona['Date of Contact']
data_MilanCrona=data_MilanCrona.drop(["Account manager","Client Name"], axis=1)
data_MilanCrona_1=data_MilanCrona.resample('M').count()
data_MilanCrona_1.head()
# Out:
# /Anaconda/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#                  Date of Contact
# Date of Contact
# 2013-10-31                    14
# 2013-11-30                     3
# 2013-12-31                     4
# 2014-01-31                     4
# 2014-02-28                     5

# %%
# data5.plot.bar(figsize=(20, 8))

# %%
data6=data_MilanCrona_1.sort_values('Date of Contact', ascending=True)

data6.plot.barh(figsize=(10,15), title='Contacts made by Account Manager: Milan Crona')

# %% [markdown]
# ## 2. Split out the contacts made by Account Manager: Aidan Pouros, name it as data_AidanPouros

# %%
data_AidanPouros=data.groupby(['Account manager']).get_group('Aidan Pouros')

# Convert that column into a datetime datatype
data_AidanPouros['Date of Contact'] = pd.to_datetime(data_AidanPouros['Date of Contact'])
# Set the datetime column as the index
data_AidanPouros.index = data_AidanPouros['Date of Contact']
data_AidanPouros=data_AidanPouros.drop(["Account manager","Client Name"], axis=1)
data_AidanPouros_1=data_AidanPouros.resample('M').count()

data_AidanPouros_2=data_AidanPouros_1.sort_values('Date of Contact', ascending=True)

data_AidanPouros_2.plot.barh(figsize=(10,15),title='Contacts made by Account Manager: Aidan Pouros')
# Out:
# /Anaconda/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.

# %% [markdown]
# ## 3. Split out the contacts made by Account Manager: Chauncey Dach, name it as data_ChaunceyDach

# %%
data_ChaunceyDach=data.groupby(['Account manager']).get_group('Chauncey Dach')

# Convert that column into a datetime datatype
data_ChaunceyDach['Date of Contact'] = pd.to_datetime(data_ChaunceyDach['Date of Contact'])
# Set the datetime column as the index
data_ChaunceyDach.index = data_ChaunceyDach['Date of Contact']
data_ChaunceyDach=data_ChaunceyDach.drop(["Account manager","Client Name"], axis=1)
data_ChaunceyDach_1=data_ChaunceyDach.resample('M').count()

data_ChaunceyDach_2=data_ChaunceyDach_1.sort_values('Date of Contact', ascending=True)

data_ChaunceyDach_2.plot.barh(figsize=(10,15),title='Contacts made by Account Manager: Chauncey Dach')
# Out:
# /Anaconda/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.

# %% [markdown]
# ## 4. Split out the contacts made by Account Manager: Rigoberto White, name it as data_RigobertoWhite

# %%
data2.size()
# Out:
# Account manager
# Aidan Pouros       239
# Chauncey Dach      253
# Milan Crona        286
# Rigoberto White    222
# dtype: int64

# %%
data_RigobertoWhite=data.groupby(['Account manager']).get_group('Rigoberto White')

# Convert that column into a datetime datatype
data_RigobertoWhite['Date of Contact'] = pd.to_datetime(data_RigobertoWhite['Date of Contact'])
# Set the datetime column as the index
data_RigobertoWhite.index = data_RigobertoWhite['Date of Contact']
data_RigobertoWhite=data_RigobertoWhite.drop(["Account manager","Client Name"], axis=1)
data_RigobertoWhite_1=data_RigobertoWhite.resample('M').count()

data_RigobertoWhite_2=data_RigobertoWhite_1.sort_values('Date of Contact', ascending=True)

data_RigobertoWhite_2.plot.barh(figsize=(10,15),title='Contacts made by Account Manager: Rigoberto White')
# Out:
# /Anaconda/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.

# %% [markdown]
# # Conclusion: All the account managers contact their clients more frequently in October
